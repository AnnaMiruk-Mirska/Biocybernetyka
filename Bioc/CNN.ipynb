# %% [markdown]
# #### CNN Classification (Keras Tensorflow)

# %%
# coding= UTF-8
import numpy as np
import keras 
from keras.models import Sequential 
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

# Load data 
X = np.load("feat.npy")
y = np.load('label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1]) 
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 233)

# Need to reshape you data to have a spatial dimension for Conv1d to make sense
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# Neural Network Construction
model = Sequential()

# Neural Network Architecture
# Using 1D Convolutions (approriate for audio files)

# first layer has 64 convolution filters 
model.add(Conv1D(64, 3, activation='relu', padding='same', input_shape = (number_of_features, 1))) 
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(3))
model.add(Conv1D(32, 3, padding='same', activation='relu'))
model.add(Conv1D(32, 3, padding='same', activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))

model.add(Dense(number_of_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# Convert label to onehot
y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Train Network
model.fit(X_train, y_train, batch_size=32, epochs=90)

# Evaluate model's accuracy with test data
score, acc = model.evaluate(X_test, y_test, batch_size=32) # Computes the loss & accuracy based on the input you pass it

print('Test score:', score) #loss
print('Test accuracy:', acc)
# Out:
# Epoch 1/90
# 32/32 [==============================] - 4s 19ms/step - loss: 1.3183 - accuracy: 0.4378
# Epoch 2/90
# 32/32 [==============================] - 1s 19ms/step - loss: 0.9587 - accuracy: 0.5392
# Epoch 3/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.8277 - accuracy: 0.6145
# Epoch 4/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.7036 - accuracy: 0.7038
# Epoch 5/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.6526 - accuracy: 0.7048
# Epoch 6/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.6087 - accuracy: 0.7510
# Epoch 7/90
# 32/32 [==============================] - 1s 17ms/step - loss: 0.5539 - accuracy: 0.7590
# Epoch 8/90
# 32/32 [==============================] - 1s 18ms/step - loss: 0.5491 - accuracy: 0.7671
# Epoch 9/90
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4542 - accuracy: 0.7952
# Epoch 10/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.4674 - accuracy: 0.8002
# Epoch 11/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.4448 - accuracy: 0.8102
# Epoch 12/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.4158 - accuracy: 0.8163
# Epoch 13/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.4122 - accuracy: 0.8253
# Epoch 14/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3801 - accuracy: 0.8394
# Epoch 15/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3494 - accuracy: 0.8424
# Epoch 16/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3777 - accuracy: 0.8554
# Epoch 17/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3360 - accuracy: 0.8474
# Epoch 18/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3361 - accuracy: 0.8504
# Epoch 19/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2920 - accuracy: 0.8685
# Epoch 20/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.3167 - accuracy: 0.8645
# Epoch 21/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.3001 - accuracy: 0.8795
# Epoch 22/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2796 - accuracy: 0.8876
# Epoch 23/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2712 - accuracy: 0.8896
# Epoch 24/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2557 - accuracy: 0.8855
# Epoch 25/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2573 - accuracy: 0.8956
# Epoch 26/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2532 - accuracy: 0.8936
# Epoch 27/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2368 - accuracy: 0.8936
# Epoch 28/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2859 - accuracy: 0.8926
# Epoch 29/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2484 - accuracy: 0.9006
# Epoch 30/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2563 - accuracy: 0.9096
# Epoch 31/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.2233 - accuracy: 0.9076
# Epoch 32/90
# 32/32 [==============================] - 0s 15ms/step - loss: 0.2262 - accuracy: 0.9046
# Epoch 33/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.2308 - accuracy: 0.8996
# Epoch 34/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2102 - accuracy: 0.9227
# Epoch 35/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.2070 - accuracy: 0.9157
# Epoch 36/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2111 - accuracy: 0.9127
# Epoch 37/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2080 - accuracy: 0.9016
# Epoch 38/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2078 - accuracy: 0.9177
# Epoch 39/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1982 - accuracy: 0.9177
# Epoch 40/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.2066 - accuracy: 0.9167
# Epoch 41/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1909 - accuracy: 0.9287
# Epoch 42/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1900 - accuracy: 0.9197
# Epoch 43/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.2086 - accuracy: 0.9177
# Epoch 44/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1822 - accuracy: 0.9217
# Epoch 45/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.1781 - accuracy: 0.9127
# Epoch 46/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1523 - accuracy: 0.9408
# Epoch 47/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1779 - accuracy: 0.9207
# Epoch 48/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1532 - accuracy: 0.9388
# Epoch 49/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1693 - accuracy: 0.9317
# Epoch 50/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1515 - accuracy: 0.9357
# Epoch 51/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1670 - accuracy: 0.9257
# Epoch 52/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1652 - accuracy: 0.9367
# Epoch 53/90
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1715 - accuracy: 0.9337
# Epoch 54/90
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1374 - accuracy: 0.9468
# Epoch 55/90
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1528 - accuracy: 0.9398
# Epoch 56/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1431 - accuracy: 0.9398
# Epoch 57/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1543 - accuracy: 0.9327
# Epoch 58/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1414 - accuracy: 0.9408
# Epoch 59/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1350 - accuracy: 0.9418
# Epoch 60/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.1351 - accuracy: 0.9448
# Epoch 61/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1400 - accuracy: 0.9538
# Epoch 62/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1459 - accuracy: 0.9398
# Epoch 63/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1387 - accuracy: 0.9418
# Epoch 64/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1201 - accuracy: 0.9498
# Epoch 65/90
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1306 - accuracy: 0.9488
# Epoch 66/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1217 - accuracy: 0.9528
# Epoch 67/90
# 32/32 [==============================] - 0s 13ms/step - loss: 0.1302 - accuracy: 0.9468
# Epoch 68/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1121 - accuracy: 0.9488
# Epoch 69/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1329 - accuracy: 0.9508
# Epoch 70/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1138 - accuracy: 0.9568
# Epoch 71/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1096 - accuracy: 0.9528
# Epoch 72/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1259 - accuracy: 0.9528
# Epoch 73/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1058 - accuracy: 0.9608
# Epoch 74/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1056 - accuracy: 0.9598
# Epoch 75/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.1109 - accuracy: 0.9518
# Epoch 76/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1064 - accuracy: 0.9548
# Epoch 77/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1250 - accuracy: 0.9478
# Epoch 78/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1000 - accuracy: 0.9618
# Epoch 79/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1089 - accuracy: 0.9518
# Epoch 80/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.1108 - accuracy: 0.9528
# Epoch 81/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1021 - accuracy: 0.9608
# Epoch 82/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1392 - accuracy: 0.9528
# Epoch 83/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0881 - accuracy: 0.9739
# Epoch 84/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1155 - accuracy: 0.9538
# Epoch 85/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0888 - accuracy: 0.9679
# Epoch 86/90
# 32/32 [==============================] - 0s 11ms/step - loss: 0.0972 - accuracy: 0.9578
# Epoch 87/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0958 - accuracy: 0.9608
# Epoch 88/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0969 - accuracy: 0.9659
# Epoch 89/90
# 32/32 [==============================] - 0s 10ms/step - loss: 0.1065 - accuracy: 0.9538
# Epoch 90/90
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0860 - accuracy: 0.9649
# 14/14 [==============================] - 1s 5ms/step - loss: 0.4059 - accuracy: 0.9182
# Test score: 0.4059002995491028
# Test accuracy: 0.9182242751121521
