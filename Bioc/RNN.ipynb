# %% [markdown]
# #### RNN Classification (Keras Tensorflow)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (65.5.1)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.8.0)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: packaging in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.25.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.5.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\acer\pycharmprojects\imageeditor\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# coding= UTF-8
import os
import numpy as np
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import LSTM  
from keras.layers import Dense
from keras.optimizers import Adam

# Load data 
X = np.load("feat.npy")
y = np.load('label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1]) 
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 230)


# Reshape data for LSTM (Samples, Timesteps, Features)
X_train = np.expand_dims(X_train, axis=2) #(280,193,1)
X_test = np.expand_dims(X_test, axis=2)

y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Build RNN Neural Network
print('Build LSTM RNN model ...')
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=X_train.shape[1:]))
model.add(LSTM(32, return_sequences=False))

#model.add(LSTM(16, return_sequences=False))
model.add(Dense(number_of_classes, activation='softmax'))
          
print("Compiling ...")
model.compile(loss='categorical_crossentropy', # for multiple classes
              optimizer='rmsprop', 
              metrics=['accuracy'])

print(model.summary())

print("Training ...")
model.fit(X_train, y_train, batch_size=64, epochs=60)

print("\nValidating ...")
score, accuracy = model.evaluate(X_test, y_test, batch_size=32, verbose=1)
print("Loss:  ", score)
print("Accuracy:  ", accuracy)
# Out:
# Build LSTM RNN model ...
# Compiling ...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 23, 256)           264192
#
#  lstm_1 (LSTM)               (None, 32)                36992
#
#  dense (Dense)               (None, 3)                 99
#
# =================================================================
# Total params: 301283 (1.15 MB)
# Trainable params: 301283 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training ...
# Epoch 1/60
# 16/16 [==============================] - 15s 150ms/step - loss: 1.0305 - accuracy: 0.4709
# Epoch 2/60
# 16/16 [==============================] - 2s 152ms/step - loss: 0.8633 - accuracy: 0.6024
# Epoch 3/60
# 16/16 [==============================] - 2s 149ms/step - loss: 0.7663 - accuracy: 0.6486
# Epoch 4/60
# 16/16 [==============================] - 2s 156ms/step - loss: 0.6940 - accuracy: 0.6948
# Epoch 5/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.6315 - accuracy: 0.7088
# Epoch 6/60
# 16/16 [==============================] - 2s 141ms/step - loss: 0.5863 - accuracy: 0.7309
# Epoch 7/60
# 16/16 [==============================] - 2s 135ms/step - loss: 0.5834 - accuracy: 0.7380
# Epoch 8/60
# 16/16 [==============================] - 2s 137ms/step - loss: 0.5388 - accuracy: 0.7671
# Epoch 9/60
# 16/16 [==============================] - 2s 141ms/step - loss: 0.5226 - accuracy: 0.7721
# Epoch 10/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.5053 - accuracy: 0.7771
# Epoch 11/60
# 16/16 [==============================] - 2s 147ms/step - loss: 0.5096 - accuracy: 0.7651
# Epoch 12/60
# 16/16 [==============================] - 2s 150ms/step - loss: 0.4604 - accuracy: 0.7962
# Epoch 13/60
# 16/16 [==============================] - 2s 151ms/step - loss: 0.4731 - accuracy: 0.7821
# Epoch 14/60
# 16/16 [==============================] - 2s 149ms/step - loss: 0.4592 - accuracy: 0.7882
# Epoch 15/60
# 16/16 [==============================] - 2s 149ms/step - loss: 0.4403 - accuracy: 0.7942
# Epoch 16/60
# 16/16 [==============================] - 2s 147ms/step - loss: 0.4363 - accuracy: 0.8012
# Epoch 17/60
# 16/16 [==============================] - 2s 149ms/step - loss: 0.3995 - accuracy: 0.8233
# Epoch 18/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.4303 - accuracy: 0.8032
# Epoch 19/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.3845 - accuracy: 0.8233
# Epoch 20/60
# 16/16 [==============================] - 2s 139ms/step - loss: 0.3822 - accuracy: 0.8303
# Epoch 21/60
# 16/16 [==============================] - 2s 140ms/step - loss: 0.3699 - accuracy: 0.8303
# Epoch 22/60
# 16/16 [==============================] - 2s 139ms/step - loss: 0.3374 - accuracy: 0.8444
# Epoch 23/60
# 16/16 [==============================] - 2s 144ms/step - loss: 0.3683 - accuracy: 0.8273
# Epoch 24/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.3401 - accuracy: 0.8404
# Epoch 25/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.3234 - accuracy: 0.8454
# Epoch 26/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.3096 - accuracy: 0.8584
# Epoch 27/60
# 16/16 [==============================] - 2s 149ms/step - loss: 0.2997 - accuracy: 0.8524
# Epoch 28/60
# 16/16 [==============================] - 2s 154ms/step - loss: 0.2916 - accuracy: 0.8655
# Epoch 29/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.2779 - accuracy: 0.8705
# Epoch 30/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.2766 - accuracy: 0.8675
# Epoch 31/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.2631 - accuracy: 0.8685
# Epoch 32/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.2541 - accuracy: 0.8876
# Epoch 33/60
# 16/16 [==============================] - 2s 150ms/step - loss: 0.2459 - accuracy: 0.8916
# Epoch 34/60
# 16/16 [==============================] - 2s 150ms/step - loss: 0.2343 - accuracy: 0.8976
# Epoch 35/60
# 16/16 [==============================] - 2s 143ms/step - loss: 0.2560 - accuracy: 0.8835
# Epoch 36/60
# 16/16 [==============================] - 2s 141ms/step - loss: 0.2488 - accuracy: 0.8876
# Epoch 37/60
# 16/16 [==============================] - 2s 142ms/step - loss: 0.2064 - accuracy: 0.9096
# Epoch 38/60
# 16/16 [==============================] - 2s 144ms/step - loss: 0.2186 - accuracy: 0.9056
# Epoch 39/60
# 16/16 [==============================] - 2s 147ms/step - loss: 0.2240 - accuracy: 0.9116
# Epoch 40/60
# 16/16 [==============================] - 2s 147ms/step - loss: 0.1933 - accuracy: 0.9096
# Epoch 41/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.2098 - accuracy: 0.9116
# Epoch 42/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.1815 - accuracy: 0.9197
# Epoch 43/60
# 16/16 [==============================] - 2s 156ms/step - loss: 0.1836 - accuracy: 0.9267
# Epoch 44/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.1597 - accuracy: 0.9307
# Epoch 45/60
# 16/16 [==============================] - 2s 144ms/step - loss: 0.1781 - accuracy: 0.9207
# Epoch 46/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.1603 - accuracy: 0.9357
# Epoch 47/60
# 16/16 [==============================] - 2s 153ms/step - loss: 0.1504 - accuracy: 0.9327
# Epoch 48/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.1671 - accuracy: 0.9317
# Epoch 49/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.1448 - accuracy: 0.9388
# Epoch 50/60
# 16/16 [==============================] - 2s 136ms/step - loss: 0.1495 - accuracy: 0.9357
# Epoch 51/60
# 16/16 [==============================] - 2s 137ms/step - loss: 0.1487 - accuracy: 0.9327
# Epoch 52/60
# 16/16 [==============================] - 2s 137ms/step - loss: 0.1311 - accuracy: 0.9408
# Epoch 53/60
# 16/16 [==============================] - 2s 142ms/step - loss: 0.1217 - accuracy: 0.9558
# Epoch 54/60
# 16/16 [==============================] - 2s 141ms/step - loss: 0.1588 - accuracy: 0.9367
# Epoch 55/60
# 16/16 [==============================] - 2s 145ms/step - loss: 0.1136 - accuracy: 0.9588
# Epoch 56/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.1420 - accuracy: 0.9317
# Epoch 57/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.1203 - accuracy: 0.9498
# Epoch 58/60
# 16/16 [==============================] - 2s 148ms/step - loss: 0.1146 - accuracy: 0.9548
# Epoch 59/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0837 - accuracy: 0.9669
# Epoch 60/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.1424 - accuracy: 0.9448
#
# Validating ...
# 14/14 [==============================] - 3s 54ms/step - loss: 0.5761 - accuracy: 0.7944
# Loss:   0.5760781168937683
# Accuracy:   0.7943925261497498
